# %% [markdown]
# # import library

# %%
import tifffile as tiff
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow.keras.layers import Input, Concatenate, Conv2D, LeakyReLU, BatchNormalization, Conv2DTranspose, Activation, Dropout, Add, UpSampling2D
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from skimage import exposure
import os
import time
from tensorflow.keras.callbacks import TensorBoard

# %%
current_time = time.strftime("%m%d_%H%M")

result_dir = os.path.join(os.getcwd(), 'result', f'logs_{current_time}')
os.makedirs(result_dir, exist_ok=True)

log_dir = os.path.join(os.getcwd(), 'logs', f'logs_{current_time}')
os.makedirs(log_dir, exist_ok=True)

print(f'Result directory created: {result_dir}')
print(f'log directory created: {log_dir}')

Epoch = 200
batch = 32
# Out:
# Result directory created: /jsm0707/GAN/result/logs_0808_0416
# log directory created: /jsm0707/GAN/logs/logs_0808_0416

# %% [markdown]
# # Data load

# %%
def load_tif_files(directory, target_size=(256, 256)):
    files = sorted([os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.tif')])
    data = []
    for file in files:
        img = tiff.imread(file)
        img_resized = cv2.resize(img, target_size)
        data.append(img_resized)
    return np.array(data)

def load_dataset(x_directory, y_directory):
    x_data = load_tif_files(x_directory)
    y_data = load_tif_files(y_directory)
    return x_data, y_data

def contrast(image): 
    valid_data = image[np.logical_and(image != np.inf, image != -np.inf)] 
    in_low, in_high = np.percentile(valid_data, (2, 98))
    image = exposure.rescale_intensity(image, in_range=(in_low, in_high))
    return image

def load_data(batch_size, X, y):
    i = np.random.randint(0, int(len(X) / batch_size))
    img_A = (np.array(X[i:i + batch_size]) / 5000.0) - 1
    img_B = (np.array(y[i:i + batch_size]) / 5000.0) - 1
    return img_A, img_B

def load_batch(batch_size, X, y):
    for i in range(int(len(X) / batch_size)):
        img_A = (X[i:i + batch_size] / 5000.0) - 1
        img_B = (y[i:i + batch_size] / 5000.0) - 1
        yield img_A, img_B

# %% [markdown]
# # Define Discriminator

# %%
def define_discriminator(image_shape):
    init = RandomNormal(stddev=0.02)
    in_src_image = Input(shape=image_shape)
    in_target_image = Input(shape=image_shape)
    merged = Concatenate()([in_src_image, in_target_image])
    d = Conv2D(64, (4, 4), strides=(2, 2), padding='same', kernel_initializer=init)(merged)
    d = LeakyReLU(alpha=0.2)(d)
    d = Conv2D(128, (4, 4), strides=(2, 2), padding='same', kernel_initializer=init)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Conv2D(256, (4, 4), strides=(2, 2), padding='same', kernel_initializer=init)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Conv2D(512, (4, 4), strides=(2, 2), padding='same', kernel_initializer=init)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Conv2D(512, (4, 4), padding='same', kernel_initializer=init)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    patch_out = Conv2D(1, (4, 4), padding='same', kernel_initializer=init)(d)
    patch_out = Activation('sigmoid')(patch_out)
    model = Model([in_src_image, in_target_image], patch_out)
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
    return model

# %% [markdown]
# # Define Generator

# %%
def define_encoder_block(layer_in, n_filters, batchnorm=True):
    init = RandomNormal(stddev=0.02)
    g = Conv2D(n_filters, (4, 4), strides=(2, 2), padding='same', kernel_initializer=init)(layer_in)
    if batchnorm:
        g = BatchNormalization()(g, training=True)
    g = LeakyReLU(alpha=0.2)(g)
    return g

def decoder_block(layer_in, skip_in, n_filters, dropout=True):
    init = RandomNormal(stddev=0.02)
    g = Conv2DTranspose(n_filters, (4, 4), strides=(2, 2), padding='same', kernel_initializer=init)(layer_in)
    g = BatchNormalization()(g, training=True)
    if dropout:
        g = Dropout(0.5)(g, training=True)
    if g.shape[1] != skip_in.shape[1] or g.shape[2] != skip_in.shape[2]:
        skip_in = UpSampling2D(size=(g.shape[1] // skip_in.shape[1], g.shape[2] // skip_in.shape[2]))(skip_in)
    g = Concatenate()([g, skip_in])
    g = Activation('relu')(g)
    return g

def residual_block(layer_in, n_filters, kernel_size=(3,3)):
    init = RandomNormal(stddev=0.02)
    g = Conv2D(n_filters, kernel_size, padding='same', kernel_initializer=init)(layer_in)
    g = BatchNormalization()(g, training=True)
    g = Activation('relu')(g)
    g = Conv2D(n_filters, kernel_size, padding='same', kernel_initializer=init)(g)
    g = BatchNormalization()(g, training=True)
    g = Add()([g, layer_in])
    return g

def define_generator(image_shape):
    init = RandomNormal(stddev=0.02)
    in_image = Input(shape=image_shape)
    e1 = define_encoder_block(in_image, 64, batchnorm=False)
    e2 = define_encoder_block(e1, 128)
    e3 = define_encoder_block(e2, 256)
    e4 = define_encoder_block(e3, 512)
    e5 = define_encoder_block(e4, 512)
    e6 = define_encoder_block(e5, 512)
    e7 = define_encoder_block(e6, 512)
    b = Conv2D(512, (4, 4), strides=(2, 2), padding='same', kernel_initializer=init)(e7)
    b = Activation('relu')(b)
    r1 = residual_block(b, 512)
    r2 = residual_block(r1, 512)
    r3 = residual_block(r2, 512)
    d1 = decoder_block(r3, e7, 512)
    d2 = decoder_block(d1, e6, 512)
    d3 = decoder_block(d2, e5, 512)
    d4 = decoder_block(d3, e4, 512, dropout=False)
    d5 = decoder_block(d4, e3, 256, dropout=False)
    d6 = decoder_block(d5, e2, 128, dropout=False)
    d7 = decoder_block(d6, e1, 64, dropout=False)
    g = Conv2DTranspose(image_shape[-1], (4, 4), strides=(2, 2), padding='same', kernel_initializer=init)(d7)
    out_image = Activation('tanh')(g)
    model = Model(in_image, out_image)
    return model

# %% [markdown]
# # Define Gan

# %%
def define_gan(g_model, d_model, image_shape):
    for layer in d_model.layers:
        if not isinstance(layer, BatchNormalization):
            layer.trainable = False
    in_src = Input(shape=image_shape)
    gen_out = g_model(in_src)
    dis_out = d_model([in_src, gen_out])
    model = Model(in_src, [dis_out, gen_out])
    opt = Adam(learning_rate=0.0001, beta_1=0.5)
    model.compile(loss=['binary_crossentropy', 'mae'], optimizer=opt, loss_weights=[1, 100])
    return model

# %%
def generate_real_samples(n_samples, patch_shape, X, y):
    trainA, trainB = load_data(n_samples, X, y)
    ix = np.random.randint(0, trainA.shape[0], n_samples)
    X1, X2 = trainA[ix], trainB[ix]
    y = np.ones((n_samples, patch_shape, patch_shape, 1))
    return [X1, X2], y

def generate_fake_samples(g_model, samples, patch_shape):
    X = g_model.predict(samples)
    y = np.zeros((len(X), patch_shape, patch_shape, 1))
    return X, y

def summarize_performance(step, g_model, result_dir, dataset, n_samples, X, y):
    [X_realA, X_realB], _ = generate_real_samples(n_samples, 1, X, y)
    X_fakeB, _ = generate_fake_samples(g_model, X_realA, 1)
    gen_imgs = [X_realA, X_fakeB, X_realB]
    titles = ['Condition', 'Generated', 'Original']
    fig, axs = plt.subplots(3, n_samples, figsize=(20, 20))
    for i in range(3):
        for j in range(n_samples):
            image = gen_imgs[i][j]
            rescaled_image = (image + 1) * 5000
            axs[i, j].imshow(contrast(rescaled_image / 10000), cmap='gray')
            axs[i, j].set_title(titles[i])
            axs[i, j].axis('off')
    filename = os.path.join(result_dir, f'{dataset}_plot_{step:06d}.png')
    fig.savefig(filename)
    plt.close(fig)

# %% [markdown]
# # Training

# %%
tensorboard_callback = TensorBoard(log_dir=log_dir)
file_writer = tf.summary.create_file_writer(log_dir)

# %%
def train_on_dataset(dataset, d_model, g_model, gan_model, n_epochs, n_batch, result_dir, d_filename, g_filename, file_writer, update_ratio=5):
    x_directory = os.path.join(os.getcwd(), 'test_image', dataset)
    y_directory = os.path.join(os.getcwd(), 'test_image', 'subset_512')
    X, y = load_dataset(x_directory, y_directory)
    print(f'Training on {dataset}: X shape: {X.shape}, y shape: {y.shape}')

    n_patch = d_model.output_shape[1]
    for epoch in range(1, n_epochs + 1):
        for batch_i, (trainA, trainB) in enumerate(load_batch(n_batch, X, y)):
            [X_realA, X_realB], y_real = generate_real_samples(n_batch, n_patch, X, y)
            X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)

            if batch_i % update_ratio == 0:
                d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
                d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
                with file_writer.as_default():
                    tf.summary.scalar('D1_loss', d_loss1, step=epoch)
                    tf.summary.scalar('D2_loss', d_loss2, step=epoch)
            
            g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
            with file_writer.as_default():
                tf.summary.scalar('G_loss', g_loss, step=epoch)

        summarize_performance(epoch, g_model, result_dir, dataset, n_samples=3, X=X, y=y)
        print(f'[Epoch {epoch}] D1_loss: {d_loss1:.3f}, D2_loss: {d_loss2:.3f}, G_loss: {g_loss:.3f}')
        g_model.save(g_filename)
        d_model.save(d_filename)

# %%
# Directories for datasets
datasets = ['subset_512_8x8', 'subset_512_4x4', 'subset_512_2x2']

# Sequentially train on each dataset
image_shape = (256, 256, 1)
d_model = define_discriminator(image_shape)
g_model = define_generator(image_shape)
gan_model = define_gan(g_model, d_model, image_shape)

for dataset in datasets:
    g_filename = os.path.join(result_dir, f'g_model_{dataset}.h5')
    d_filename = os.path.join(result_dir, f'd_model_{dataset}.h5')

    if os.path.exists(g_filename):
        g_model.load_weights(g_filename)
    if os.path.exists(d_filename):
        d_model.load_weights(d_filename)

    train_on_dataset(dataset, d_model, g_model, gan_model, n_epochs=Epoch, n_batch=batch, result_dir=result_dir, d_filename=d_filename, g_filename=g_filename, file_writer=file_writer)
# Out:
# Training on subset_512_8x8: X shape: (864, 256, 256), y shape: (864, 256, 256)
# [Epoch 1] D1_loss: 0.168, D2_loss: 0.310, G_loss: 51.273
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 2] D1_loss: 0.210, D2_loss: 0.299, G_loss: 31.150
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 3] D1_loss: 0.027, D2_loss: 0.036, G_loss: 20.780
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 4] D1_loss: 0.205, D2_loss: 1.717, G_loss: 11.000
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 5] D1_loss: 0.420, D2_loss: 0.426, G_loss: 7.503
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 6] D1_loss: 0.405, D2_loss: 0.410, G_loss: 5.246
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 7] D1_loss: 0.396, D2_loss: 0.403, G_loss: 3.901
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 8] D1_loss: 0.391, D2_loss: 0.398, G_loss: 3.083
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 9] D1_loss: 0.387, D2_loss: 0.394, G_loss: 2.569
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 10] D1_loss: 0.384, D2_loss: 0.392, G_loss: 2.210
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 11] D1_loss: 0.382, D2_loss: 0.390, G_loss: 1.971
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 12] D1_loss: 0.380, D2_loss: 0.388, G_loss: 1.786
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 13] D1_loss: 0.378, D2_loss: 0.387, G_loss: 1.634
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 14] D1_loss: 0.377, D2_loss: 0.386, G_loss: 1.548
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 15] D1_loss: 0.376, D2_loss: 0.384, G_loss: 1.451
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 16] D1_loss: 0.374, D2_loss: 0.384, G_loss: 1.387
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 17] D1_loss: 0.374, D2_loss: 0.382, G_loss: 1.323
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 18] D1_loss: 0.372, D2_loss: 0.382, G_loss: 1.275
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 19] D1_loss: 0.372, D2_loss: 0.381, G_loss: 1.245
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 20] D1_loss: 0.371, D2_loss: 0.381, G_loss: 1.215
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 21] D1_loss: 0.370, D2_loss: 0.380, G_loss: 1.190
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 22] D1_loss: 0.369, D2_loss: 0.380, G_loss: 1.161
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 23] D1_loss: 0.369, D2_loss: 0.379, G_loss: 1.126
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 24] D1_loss: 0.368, D2_loss: 0.379, G_loss: 1.129
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 25] D1_loss: 0.367, D2_loss: 0.378, G_loss: 1.103
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 26] D1_loss: 0.367, D2_loss: 0.378, G_loss: 1.097
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 27] D1_loss: 0.366, D2_loss: 0.378, G_loss: 1.081
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 28] D1_loss: 0.366, D2_loss: 0.378, G_loss: 1.065
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 29] D1_loss: 0.366, D2_loss: 0.377, G_loss: 1.049
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 30] D1_loss: 0.365, D2_loss: 0.377, G_loss: 1.048
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 31] D1_loss: 0.364, D2_loss: 0.377, G_loss: 1.039
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 32] D1_loss: 0.364, D2_loss: 0.376, G_loss: 1.032
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 33] D1_loss: 0.364, D2_loss: 0.376, G_loss: 1.034
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 34] D1_loss: 0.363, D2_loss: 0.376, G_loss: 1.018
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 35] D1_loss: 0.363, D2_loss: 0.376, G_loss: 1.016
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 36] D1_loss: 0.362, D2_loss: 0.376, G_loss: 1.000
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 37] D1_loss: 0.362, D2_loss: 0.375, G_loss: 0.995
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 38] D1_loss: 0.361, D2_loss: 0.376, G_loss: 1.009
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 39] D1_loss: 0.361, D2_loss: 0.375, G_loss: 1.000
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 40] D1_loss: 0.361, D2_loss: 0.375, G_loss: 0.996
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 41] D1_loss: 0.361, D2_loss: 0.374, G_loss: 0.985
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 42] D1_loss: 0.360, D2_loss: 0.375, G_loss: 0.990
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 43] D1_loss: 0.360, D2_loss: 0.374, G_loss: 0.984
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 44] D1_loss: 0.360, D2_loss: 0.374, G_loss: 0.986
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 45] D1_loss: 0.360, D2_loss: 0.374, G_loss: 0.978
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 46] D1_loss: 0.359, D2_loss: 0.374, G_loss: 0.973
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 47] D1_loss: 0.359, D2_loss: 0.373, G_loss: 0.975
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 48] D1_loss: 0.359, D2_loss: 0.374, G_loss: 0.953
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 49] D1_loss: 0.359, D2_loss: 0.373, G_loss: 0.972
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 50] D1_loss: 0.359, D2_loss: 0.373, G_loss: 0.959
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 51] D1_loss: 0.358, D2_loss: 0.373, G_loss: 0.964
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 52] D1_loss: 0.358, D2_loss: 0.372, G_loss: 0.947
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 53] D1_loss: 0.357, D2_loss: 0.373, G_loss: 0.950
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 54] D1_loss: 0.357, D2_loss: 0.373, G_loss: 0.954
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 55] D1_loss: 0.357, D2_loss: 0.372, G_loss: 0.947
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 56] D1_loss: 0.356, D2_loss: 0.372, G_loss: 0.948
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 57] D1_loss: 0.356, D2_loss: 0.372, G_loss: 0.952
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 58] D1_loss: 0.356, D2_loss: 0.372, G_loss: 0.937
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 59] D1_loss: 0.356, D2_loss: 0.372, G_loss: 0.926
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 60] D1_loss: 0.356, D2_loss: 0.372, G_loss: 0.931
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 61] D1_loss: 0.355, D2_loss: 0.372, G_loss: 0.936
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 62] D1_loss: 0.355, D2_loss: 0.372, G_loss: 0.938
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 63] D1_loss: 0.355, D2_loss: 0.372, G_loss: 0.935
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 64] D1_loss: 0.355, D2_loss: 0.372, G_loss: 0.928
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 65] D1_loss: 0.354, D2_loss: 0.371, G_loss: 0.925
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 66] D1_loss: 0.354, D2_loss: 0.371, G_loss: 0.926
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 67] D1_loss: 0.354, D2_loss: 0.372, G_loss: 0.937
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 68] D1_loss: 0.354, D2_loss: 0.371, G_loss: 0.933
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 69] D1_loss: 0.353, D2_loss: 0.371, G_loss: 0.928
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 70] D1_loss: 0.353, D2_loss: 0.372, G_loss: 0.930
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 71] D1_loss: 0.353, D2_loss: 0.372, G_loss: 0.931
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 72] D1_loss: 0.352, D2_loss: 0.372, G_loss: 0.937
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 73] D1_loss: 0.351, D2_loss: 0.371, G_loss: 0.930
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 74] D1_loss: 0.348, D2_loss: 0.373, G_loss: 0.924
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 75] D1_loss: 0.354, D2_loss: 0.378, G_loss: 0.944
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 76] D1_loss: 0.333, D2_loss: 0.372, G_loss: 0.972
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 77] D1_loss: 0.324, D2_loss: 0.354, G_loss: 0.997
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 78] D1_loss: 0.332, D2_loss: 0.334, G_loss: 1.020
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 79] D1_loss: 0.313, D2_loss: 0.311, G_loss: 1.126
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 80] D1_loss: 0.265, D2_loss: 0.328, G_loss: 1.228
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 81] D1_loss: 0.410, D2_loss: 0.378, G_loss: 1.146
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 82] D1_loss: 0.367, D2_loss: 0.426, G_loss: 0.978
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 83] D1_loss: 0.362, D2_loss: 0.367, G_loss: 1.051
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 84] D1_loss: 0.330, D2_loss: 0.404, G_loss: 1.011
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 85] D1_loss: 0.359, D2_loss: 0.371, G_loss: 1.072
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 86] D1_loss: 0.332, D2_loss: 0.394, G_loss: 1.048
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 87] D1_loss: 0.361, D2_loss: 0.408, G_loss: 1.102
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 88] D1_loss: 0.321, D2_loss: 0.403, G_loss: 1.064
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 89] D1_loss: 0.371, D2_loss: 0.358, G_loss: 1.108
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 90] D1_loss: 0.351, D2_loss: 0.382, G_loss: 1.060
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 91] D1_loss: 0.355, D2_loss: 0.357, G_loss: 1.074
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 92] D1_loss: 0.381, D2_loss: 0.354, G_loss: 1.105
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 93] D1_loss: 0.341, D2_loss: 0.365, G_loss: 1.091
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 94] D1_loss: 0.342, D2_loss: 0.381, G_loss: 1.072
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 95] D1_loss: 0.342, D2_loss: 0.370, G_loss: 1.091
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 96] D1_loss: 0.337, D2_loss: 0.352, G_loss: 1.124
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 97] D1_loss: 0.360, D2_loss: 0.363, G_loss: 1.143
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 98] D1_loss: 0.326, D2_loss: 0.381, G_loss: 1.102
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 99] D1_loss: 0.348, D2_loss: 0.343, G_loss: 1.106
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 100] D1_loss: 0.329, D2_loss: 0.360, G_loss: 1.064
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 101] D1_loss: 0.374, D2_loss: 0.358, G_loss: 1.163
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 102] D1_loss: 0.348, D2_loss: 0.366, G_loss: 1.126
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 103] D1_loss: 0.346, D2_loss: 0.376, G_loss: 1.130
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 104] D1_loss: 0.320, D2_loss: 0.380, G_loss: 1.098
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 105] D1_loss: 0.368, D2_loss: 0.353, G_loss: 1.129
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 106] D1_loss: 0.347, D2_loss: 0.362, G_loss: 1.136
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 107] D1_loss: 0.338, D2_loss: 0.375, G_loss: 1.151
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 108] D1_loss: 0.341, D2_loss: 0.379, G_loss: 1.111
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 109] D1_loss: 0.345, D2_loss: 0.372, G_loss: 1.120
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 110] D1_loss: 0.349, D2_loss: 0.357, G_loss: 1.128
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 111] D1_loss: 0.350, D2_loss: 0.376, G_loss: 1.144
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 112] D1_loss: 0.333, D2_loss: 0.370, G_loss: 1.109
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 113] D1_loss: 0.306, D2_loss: 0.393, G_loss: 1.059
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 114] D1_loss: 0.363, D2_loss: 0.354, G_loss: 1.117
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 115] D1_loss: 0.334, D2_loss: 0.393, G_loss: 1.097
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 116] D1_loss: 0.351, D2_loss: 0.367, G_loss: 1.114
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 117] D1_loss: 0.346, D2_loss: 0.354, G_loss: 1.094
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 118] D1_loss: 0.349, D2_loss: 0.351, G_loss: 1.163
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 119] D1_loss: 0.350, D2_loss: 0.355, G_loss: 1.124
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 120] D1_loss: 0.354, D2_loss: 0.356, G_loss: 1.117
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 121] D1_loss: 0.327, D2_loss: 0.412, G_loss: 1.093
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 122] D1_loss: 0.349, D2_loss: 0.363, G_loss: 1.109
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 123] D1_loss: 0.348, D2_loss: 0.359, G_loss: 1.105
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 124] D1_loss: 0.334, D2_loss: 0.390, G_loss: 1.123
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 125] D1_loss: 0.356, D2_loss: 0.364, G_loss: 1.106
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 126] D1_loss: 0.350, D2_loss: 0.356, G_loss: 1.126
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 127] D1_loss: 0.343, D2_loss: 0.354, G_loss: 1.114
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 128] D1_loss: 0.352, D2_loss: 0.335, G_loss: 1.083
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 129] D1_loss: 0.343, D2_loss: 0.373, G_loss: 1.126
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 130] D1_loss: 0.342, D2_loss: 0.369, G_loss: 1.137
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 131] D1_loss: 0.333, D2_loss: 0.361, G_loss: 1.119
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 132] D1_loss: 0.344, D2_loss: 0.370, G_loss: 1.108
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 133] D1_loss: 0.343, D2_loss: 0.379, G_loss: 1.094
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 134] D1_loss: 0.347, D2_loss: 0.362, G_loss: 1.114
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 135] D1_loss: 0.346, D2_loss: 0.358, G_loss: 1.093
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 136] D1_loss: 0.336, D2_loss: 0.382, G_loss: 1.111
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 137] D1_loss: 0.345, D2_loss: 0.361, G_loss: 1.119
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 138] D1_loss: 0.339, D2_loss: 0.365, G_loss: 1.108
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 139] D1_loss: 0.337, D2_loss: 0.362, G_loss: 1.118
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 140] D1_loss: 0.340, D2_loss: 0.358, G_loss: 1.092
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 141] D1_loss: 0.344, D2_loss: 0.363, G_loss: 1.117
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 142] D1_loss: 0.347, D2_loss: 0.339, G_loss: 1.105
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 143] D1_loss: 0.326, D2_loss: 0.393, G_loss: 1.120
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 144] D1_loss: 0.354, D2_loss: 0.366, G_loss: 1.123
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 145] D1_loss: 0.346, D2_loss: 0.362, G_loss: 1.115
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 146] D1_loss: 0.343, D2_loss: 0.362, G_loss: 1.111
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 147] D1_loss: 0.343, D2_loss: 0.362, G_loss: 1.095
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 148] D1_loss: 0.344, D2_loss: 0.363, G_loss: 1.088
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 149] D1_loss: 0.342, D2_loss: 0.366, G_loss: 1.114
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 150] D1_loss: 0.341, D2_loss: 0.377, G_loss: 1.115
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Training on subset_512_4x4: X shape: (864, 256, 256), y shape: (864, 256, 256)
# [Epoch 1] D1_loss: 0.341, D2_loss: 0.369, G_loss: 1.101
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 2] D1_loss: 0.342, D2_loss: 0.375, G_loss: 1.097
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 3] D1_loss: 0.331, D2_loss: 0.360, G_loss: 1.097
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 4] D1_loss: 0.339, D2_loss: 0.376, G_loss: 1.106
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 5] D1_loss: 0.289, D2_loss: 0.381, G_loss: 1.043
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 6] D1_loss: 0.354, D2_loss: 0.371, G_loss: 1.117
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 7] D1_loss: 0.346, D2_loss: 0.362, G_loss: 1.109
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 8] D1_loss: 0.340, D2_loss: 0.367, G_loss: 1.108
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 9] D1_loss: 0.335, D2_loss: 0.371, G_loss: 1.106
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 10] D1_loss: 0.346, D2_loss: 0.361, G_loss: 1.100
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 11] D1_loss: 0.340, D2_loss: 0.362, G_loss: 1.108
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 12] D1_loss: 0.330, D2_loss: 0.365, G_loss: 1.098
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 13] D1_loss: 0.333, D2_loss: 0.378, G_loss: 1.094
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 14] D1_loss: 0.339, D2_loss: 0.363, G_loss: 1.111
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 15] D1_loss: 0.332, D2_loss: 0.363, G_loss: 1.102
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 16] D1_loss: 0.332, D2_loss: 0.379, G_loss: 1.097
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 17] D1_loss: 0.269, D2_loss: 0.483, G_loss: 1.058
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 18] D1_loss: 0.350, D2_loss: 0.363, G_loss: 1.115
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 19] D1_loss: 0.343, D2_loss: 0.372, G_loss: 1.111
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 20] D1_loss: 0.346, D2_loss: 0.350, G_loss: 1.110
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 21] D1_loss: 0.340, D2_loss: 0.353, G_loss: 1.119
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 22] D1_loss: 0.330, D2_loss: 0.376, G_loss: 1.095
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 23] D1_loss: 0.337, D2_loss: 0.373, G_loss: 1.107
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 24] D1_loss: 0.336, D2_loss: 0.367, G_loss: 1.106
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 25] D1_loss: 0.337, D2_loss: 0.364, G_loss: 1.110
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 26] D1_loss: 0.333, D2_loss: 0.382, G_loss: 1.113
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 27] D1_loss: 0.337, D2_loss: 0.364, G_loss: 1.114
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 28] D1_loss: 0.341, D2_loss: 0.355, G_loss: 1.101
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 29] D1_loss: 0.336, D2_loss: 0.353, G_loss: 1.115
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 30] D1_loss: 0.341, D2_loss: 0.378, G_loss: 1.113
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 31] D1_loss: 0.337, D2_loss: 0.370, G_loss: 1.116
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 32] D1_loss: 0.322, D2_loss: 0.384, G_loss: 1.097
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 33] D1_loss: 0.339, D2_loss: 0.371, G_loss: 1.101
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 34] D1_loss: 0.331, D2_loss: 0.381, G_loss: 1.097
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 35] D1_loss: 0.352, D2_loss: 0.357, G_loss: 1.105
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 36] D1_loss: 0.342, D2_loss: 0.367, G_loss: 1.119
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 37] D1_loss: 0.337, D2_loss: 0.368, G_loss: 1.116
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 38] D1_loss: 0.340, D2_loss: 0.373, G_loss: 1.108
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 39] D1_loss: 0.329, D2_loss: 0.361, G_loss: 1.121
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 40] D1_loss: 0.335, D2_loss: 0.368, G_loss: 1.158
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 41] D1_loss: 0.274, D2_loss: 0.411, G_loss: 1.096
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 42] D1_loss: 0.354, D2_loss: 0.352, G_loss: 1.158
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 43] D1_loss: 0.340, D2_loss: 0.363, G_loss: 1.117
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 44] D1_loss: 0.355, D2_loss: 0.359, G_loss: 1.134
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 45] D1_loss: 0.335, D2_loss: 0.343, G_loss: 1.181
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 46] D1_loss: 0.338, D2_loss: 0.350, G_loss: 1.153
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 47] D1_loss: 0.338, D2_loss: 0.365, G_loss: 1.114
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 48] D1_loss: 0.329, D2_loss: 0.340, G_loss: 1.167
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 49] D1_loss: 0.342, D2_loss: 0.372, G_loss: 1.150
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 50] D1_loss: 0.351, D2_loss: 0.359, G_loss: 1.113
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 51] D1_loss: 0.326, D2_loss: 0.365, G_loss: 1.122
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 52] D1_loss: 0.366, D2_loss: 0.386, G_loss: 1.027
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 53] D1_loss: 0.264, D2_loss: 0.334, G_loss: 1.159
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 54] D1_loss: 0.351, D2_loss: 0.365, G_loss: 1.141
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 55] D1_loss: 0.375, D2_loss: 0.376, G_loss: 1.128
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 56] D1_loss: 0.342, D2_loss: 0.369, G_loss: 1.122
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 57] D1_loss: 0.318, D2_loss: 0.347, G_loss: 1.336
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 58] D1_loss: 0.331, D2_loss: 0.368, G_loss: 1.196
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 59] D1_loss: 0.353, D2_loss: 0.365, G_loss: 1.113
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 60] D1_loss: 0.327, D2_loss: 0.383, G_loss: 1.116
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 61] D1_loss: 0.343, D2_loss: 0.398, G_loss: 1.103
# ...
# [Epoch 81] D1_loss: 0.344, D2_loss: 0.361, G_loss: 1.142
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 82] D1_loss: 0.338, D2_loss: 0.358, G_loss: 1.131
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 83] D1_loss: 0.348, D2_loss: 0.358, G_loss: 1.131
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 84] D1_loss: 0.339, D2_loss: 0.353, G_loss: 1.125
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 85] D1_loss: 0.334, D2_loss: 0.370, G_loss: 1.122
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 86] D1_loss: 0.345, D2_loss: 0.365, G_loss: 1.125
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 87] D1_loss: 0.337, D2_loss: 0.362, G_loss: 1.130
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 88] D1_loss: 0.341, D2_loss: 0.388, G_loss: 1.127
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 89] D1_loss: 0.339, D2_loss: 0.366, G_loss: 1.136
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 90] D1_loss: 0.341, D2_loss: 0.364, G_loss: 1.137
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 91] D1_loss: 0.349, D2_loss: 0.361, G_loss: 1.122
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 92] D1_loss: 0.345, D2_loss: 0.365, G_loss: 1.131
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 93] D1_loss: 0.341, D2_loss: 0.361, G_loss: 1.119
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 94] D1_loss: 0.341, D2_loss: 0.361, G_loss: 1.120
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 95] D1_loss: 0.352, D2_loss: 0.358, G_loss: 1.128
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 96] D1_loss: 0.344, D2_loss: 0.361, G_loss: 1.126
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 97] D1_loss: 0.337, D2_loss: 0.363, G_loss: 1.129
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 98] D1_loss: 0.348, D2_loss: 0.363, G_loss: 1.135
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 99] D1_loss: 0.340, D2_loss: 0.358, G_loss: 1.127
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 100] D1_loss: 0.337, D2_loss: 0.390, G_loss: 1.143
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 101] D1_loss: 0.345, D2_loss: 0.375, G_loss: 1.142
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 102] D1_loss: 0.332, D2_loss: 0.362, G_loss: 1.141
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 103] D1_loss: 0.339, D2_loss: 0.369, G_loss: 1.154
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 104] D1_loss: 0.332, D2_loss: 0.358, G_loss: 1.130
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 105] D1_loss: 0.337, D2_loss: 0.361, G_loss: 1.138
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 106] D1_loss: 0.333, D2_loss: 0.357, G_loss: 1.143
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 107] D1_loss: 0.342, D2_loss: 0.363, G_loss: 1.144
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 108] D1_loss: 0.344, D2_loss: 0.362, G_loss: 1.150
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 109] D1_loss: 0.337, D2_loss: 0.370, G_loss: 1.141
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 110] D1_loss: 0.342, D2_loss: 0.376, G_loss: 1.128
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 111] D1_loss: 0.339, D2_loss: 0.360, G_loss: 1.139
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 112] D1_loss: 0.330, D2_loss: 0.372, G_loss: 1.137
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 113] D1_loss: 0.343, D2_loss: 0.356, G_loss: 1.159
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 114] D1_loss: 0.350, D2_loss: 0.354, G_loss: 1.133
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 115] D1_loss: 0.342, D2_loss: 0.359, G_loss: 1.148
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 116] D1_loss: 0.347, D2_loss: 0.355, G_loss: 1.163
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 117] D1_loss: 0.344, D2_loss: 0.361, G_loss: 1.164
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 118] D1_loss: 0.345, D2_loss: 0.360, G_loss: 1.128
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 119] D1_loss: 0.336, D2_loss: 0.358, G_loss: 1.149
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 120] D1_loss: 0.334, D2_loss: 0.363, G_loss: 1.146
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 121] D1_loss: 0.339, D2_loss: 0.364, G_loss: 1.146
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 122] D1_loss: 0.336, D2_loss: 0.372, G_loss: 1.135
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 123] D1_loss: 0.344, D2_loss: 0.363, G_loss: 1.141
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 124] D1_loss: 0.337, D2_loss: 0.360, G_loss: 1.138
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 125] D1_loss: 0.333, D2_loss: 0.371, G_loss: 1.143
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 126] D1_loss: 0.338, D2_loss: 0.366, G_loss: 1.145
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 127] D1_loss: 0.328, D2_loss: 0.363, G_loss: 1.191
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 128] D1_loss: 0.309, D2_loss: 0.369, G_loss: 1.152
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 129] D1_loss: 0.346, D2_loss: 0.376, G_loss: 1.155
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 130] D1_loss: 0.342, D2_loss: 0.360, G_loss: 1.157
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 131] D1_loss: 0.349, D2_loss: 0.360, G_loss: 1.147
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 132] D1_loss: 0.339, D2_loss: 0.348, G_loss: 1.185
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 133] D1_loss: 0.342, D2_loss: 0.360, G_loss: 1.148
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 134] D1_loss: 0.337, D2_loss: 0.362, G_loss: 1.144
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 135] D1_loss: 0.342, D2_loss: 0.364, G_loss: 1.159
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 136] D1_loss: 0.321, D2_loss: 0.371, G_loss: 1.165
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 137] D1_loss: 0.334, D2_loss: 0.349, G_loss: 1.156
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 138] D1_loss: 0.330, D2_loss: 0.357, G_loss: 1.221
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 139] D1_loss: 0.329, D2_loss: 0.351, G_loss: 1.199
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 140] D1_loss: 0.333, D2_loss: 0.356, G_loss: 1.180
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 141] D1_loss: 0.327, D2_loss: 0.363, G_loss: 1.194
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 142] D1_loss: 0.329, D2_loss: 0.342, G_loss: 1.199
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 143] D1_loss: 0.322, D2_loss: 0.367, G_loss: 1.140
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 144] D1_loss: 0.346, D2_loss: 0.356, G_loss: 1.195
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 145] D1_loss: 0.321, D2_loss: 0.367, G_loss: 1.275
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 146] D1_loss: 0.322, D2_loss: 0.373, G_loss: 1.066
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 147] D1_loss: 0.330, D2_loss: 0.357, G_loss: 1.135
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 148] D1_loss: 0.278, D2_loss: 0.302, G_loss: 1.243
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 149] D1_loss: 0.270, D2_loss: 0.299, G_loss: 1.261
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [Epoch 150] D1_loss: 0.282, D2_loss: 0.427, G_loss: 1.173
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # inference코드

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
import os
import matplotlib.pyplot as plt
from skimage import exposure
import cv2
import tifffile as tiff

def load_tif_file(file_path, target_size=(256, 256)):
    img = tiff.imread(file_path)
    img_resized = cv2.resize(img, target_size)
    return np.array(img_resized)

def contrast(image):
    valid_data = image[np.logical_and(image != np.inf, image != -np.inf)]
    in_low, in_high = np.percentile(valid_data, (2, 98))
    image = exposure.rescale_intensity(image, in_range=(in_low, in_high))
    return image

def visualize_results(X_realA, X_fakeB, save_path=None):
    gen_imgs = [X_realA, X_fakeB]
    titles = ['Condition', 'Generated']
    fig, axs = plt.subplots(1, 2, figsize=(20, 10))
    for i in range(2):
        image = gen_imgs[i]
        rescaled_image = (image + 1) * 5000
        axs[i].imshow(contrast(rescaled_image / 10000), cmap='gray')
        axs[i].set_title(titles[i])
        axs[i].axis('off')
    if save_path:
        fig.savefig(save_path)
    plt.show()

def perform_inference(g_model, file_path, save_path=None):
    X_realA = load_tif_file(file_path)

    X_realA = (X_realA / 5000.0) - 1

    # Ensure the input shape matches the expected shape of the model
    if len(X_realA.shape) == 2:  # Add channel dimension if missing
        X_realA = np.expand_dims(X_realA, axis=-1)
    
    # Ensure that input is 4-dimensional (batch, height, width, channels)
    X_realA = np.expand_dims(X_realA, axis=0)

    X_fakeB = g_model.predict(X_realA)

    # Ensure the output is squeezed to remove the batch dimension
    X_fakeB = np.squeeze(X_fakeB, axis=0)
    X_realA = np.squeeze(X_realA, axis=0)

    visualize_results(X_realA, X_fakeB, save_path)

# %%
# File path
file_path = os.path.join(os.getcwd(), 'test_image', 'subset_512_4x4', 'S1A_IW_GRDH_1SDV_20210105T092315_20210105T092344_036001_0437B7_42D51_subset_0_0.tif')

# Load the saved generator model
result_dir = os.path.join(os.getcwd(), 'result', 'logs_8x8_0709_1551_code1')
g_model_path = os.path.join(result_dir, 'd_model.h5')

if not os.path.exists(g_model_path):
    raise FileNotFoundError(f"Generator model not found at {g_model_path}")

# Load the generator model
g_model = load_model(g_model_path, compile=False)
print("Generator model loaded successfully.")

# Perform inference
output_image_path = os.path.join(result_dir, 'inference_result.png')
perform_inference(g_model, file_path, save_path=output_image_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-079d7fa65910> in <module>
#       7
#       8 if not os.path.exists(g_model_path):
# ----> 9     raise FileNotFoundError(f"Generator model not found at {g_model_path}")
#      10
#      11 # Load the generator model
#
# FileNotFoundError: Generator model not found at /jsm0707/GAN/result/logs_8x8_0709_1551_code1/d_model.h5
